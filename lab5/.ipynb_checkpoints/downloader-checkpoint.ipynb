# %%
from web3 import Web3
import pandas as pd
import numpy as np

# %%
DIV = 1000000000
PRICE = 3000000000

# %%
web3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/0cf0910692d24d33ae46244f3189bea8'))

# %%
print(web3.isConnected())
# Out:
# True

# %%
# checking for the latest node
print(web3.eth.blockNumber)
# Out:
# 9020974

# %%
blocks = []
last_block = 8961400 - 1000 * (35 - 2)
first_block = 8961400 - 1000 * (35 - 1)
print (first_block, last_block)
# Out:
# 8927400 8928400

# %%
for current_block in (first_block, last_block):
    c_block = web3.eth.getBlock(current_block)
    blocks.append(c_block)
    current_block += 1

# %%
print (len(blocks), '\n')
blocks[0]
# Out:
# 1000
# AttributeDict({'difficulty': 2573569997487818,
#  'extraData': HexBytes('0x472f535a2f4254504f4f4c2f0002c7d1'),
#  'gasLimit': 9929026,
#  'gasUsed': 3133147,
#  'hash': HexBytes('0xb8766ec72e3c3779bbe2fccad46c527b39360e0544c4aa1ad7b01255daf5bb67'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0xAA5c4244F05c92781C4F259913319d8ba1aCF05E',
#  'mixHash': HexBytes('0x1982277d44effa81846b3418ee014553a38b674f603e07ce9f9be7bbaedabb92'),
#  'nonce': HexBytes('0x21b8de40000f0e52'),
#  'number': 8927400,
#  'parentHash': HexBytes('0x4b101e50adad2291e6f44e5399486512a6682a092bc983f821a3face8d8abcdc'),
#  'receiptsRoot': HexBytes('0x81c8427defbe3ba157b9a3ba58706d7dff4cdf6c6084f59b83836e049fad800b'),
#  'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#  'size': 11866,
#  'stateRoot': HexBytes('0xed77c2fcd0ca7d798c9c5e6bd1ea822d746e264acad6f1c98973ec7505362e62'),
#  'timestamp': 1573662095,
#  'totalDifficulty': 12834843182239540601036,
#  'transactions': [HexBytes('0x6b053b1615e047cfeff3ae36cce1ed655b7df004252d45190cb5eeb589cc35a0'),
#   HexBytes('0xe8bef2ddf7801aec592b5a3eb763280b8d7a56a6d0440dc2b13b0864dd834e6b'),
#   HexBytes('0x1beeaa72141230f6f7938b5fff953ccae364a3b94b7568cb1c81a97edeb9195c'),
#   HexBytes('0xea0f1d971a237a4b8c82418f79dc6dc05baf77ec71cc1b81462a7f044026749d'),
#   HexBytes('0x2a27dc26e3ecd55c8426e9dcdca5196262e0ed3de0a980172a35c95e0ad8478f'),
#   HexBytes('0x1f08210e2753321dab542b094fac795fc11f14899ed418a6487b100f589d14d6'),
#   HexBytes('0x39d86f6326a2950b92ddbf4de3263b78df1d8bee5adfe89422e1a9b2890ca142'),
#   HexBytes('0x7ffbb157dc46852246a3843f335ec8e5c3d119c47109d3940d414251c6763b28'),
#   HexBytes('0xa628034cb8a9b0b37eebec25f553b37a71910f82d4dbf071771437683fe4934c'),
#   HexBytes('0x9a3abfaaeffe346e8bfdec8e47c464a3917ef1044337a7dcc92e3d3b48f65b7f'),
#   HexBytes('0x82217b549bc9ef1b6162f87827d67fa83b5d44f36bd39e5490e3dc1bb145bfed'),
#   HexBytes('0x68b866ec48f0eed241f6c9ba0af83a559c53e59dc0a9bc98329ff8e08d4b89c7'),
#   HexBytes('0x7fa56a1607b286ee4acfa753d8070e359657f49ef6fb71b209b9a80af25ea0dd'),
#   HexBytes('0x9f8cb58414de9d49aede0c8b0e7f8c958cc115eba93b33035a9565ee8e5b888d'),
#   HexBytes('0x902da60ae00435b0f62e8a33b18982ae839efb611297e37c44c60b9819aacbf9'),
#   HexBytes('0x2021d72fe11b10317c6f7bcf9c1fd6cb57599910fbc18c5df3d2aca6e49b0471'),
#   HexBytes('0x1ee90ad7f1994c33fbee45cbbd80bc03bacd9355ac89274f1ecf82030a6c4d69'),
#   HexBytes('0xc40010120e88cfbc183219c1d745749936f669af89ad6d179efb3b1554277b82'),
#   HexBytes('0xbf948df32b17d85acaf438d6a1dbb6c77a38b9afc121459cc3585dd518ea6209'),
#   HexBytes('0x28bcf20d1a3609daa578daf04d230843d5a0cce38ae940c5382e7b099aff70c6'),
#   HexBytes('0xef9ec1ec3b4193eb11068d8975791d79183eab9eda7044218c399a3c3fc5c5eb'),
#   HexBytes('0xa97241f5008ed7a8eeead740bc2b0a1766688cbf6f5a76e285920f86f7770ef5'),
#   HexBytes('0x94b33d7422ff1a13382160f68b218cab0deccd40ee1f55a5224f0043193e31aa'),
#   HexBytes('0x95015c6f479b51d497b61be85a030106665d04712eeedb1a64feccd8fc89e9c4'),
#   HexBytes('0x6e0fa0e29de4a069cd99078c6774270877ea505e7e2b084eb06f642c08662370'),
#   HexBytes('0x0e077eab801afd00678cb5ed08852d44a8266fb10548f8e0ddedef697ff1eb7c'),
#   HexBytes('0x0d2bed92369c6c95b588e6351ef6a9720422b2303f66296694c5c5ea0fedb4b1'),
#   HexBytes('0xaf237e7aa3f0d895a511407f0e38c5a8a826b1f1885d9a5a6103235b413560e3'),
#   HexBytes('0x18d97964306e153a03bd4872938659f99ce3b7a61d758c2c3e95b46635213ef6'),
#   HexBytes('0x6a0f47f1ce759a509f2292bb8f229eb4d6c5e644adf75c3bc097cc23921e3c7c'),
#   HexBytes('0x5894cee5a11b6e04fc3d851a80b95f2500bd726e03a6979b1af6b3f4eaec3c2f')],
#  'transactionsRoot': HexBytes('0x8e14977f600653acd6844ec288f35332b2efb6e9981df70230eccfb9a4205753'),
#  'uncles': []})

# %%
#gasUsed, uncles, number, gasLimit, gasprice = 3 000 000 000, 

gasused = []
uncles = []
number = []
gaslimit = []

for block in blocks:
    gasused.append(block.gasUsed)
    uncles.append(block.uncles)
    number.append(block.number)
    gaslimit.append(block.gasLimit)

gas_data = pd.DataFrame.from_dict({'number': number, 'gas_limit': gaslimit, 'gas_used': gasused, 'uncles': uncles})
gas_data
# Out:
#       number  gas_limit  gas_used uncles
# 0    8927400    9929026   3133147     []
# 1    8927401    9938721   6960816     []
# 2    8927402    9948425   9945509     []
# 3    8927403    9958139   9943134     []
# 4    8927404    9967862   8582982     []
# ..       ...        ...       ...    ...
# 995  8928395    9940682   7376567     []
# 996  8928396    9950388   7042923     []
# 997  8928397    9940672   5335647     []
# 998  8928398    9930985   9616332     []
# 999  8928399    9940682   2854200     []
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### testing shit

# %%
bla = web3.eth.getBlock(first_block)
bla
# Out:
# AttributeDict({'difficulty': 2573569997487818,
#  'extraData': HexBytes('0x472f535a2f4254504f4f4c2f0002c7d1'),
#  'gasLimit': 9929026,
#  'gasUsed': 3133147,
#  'hash': HexBytes('0xb8766ec72e3c3779bbe2fccad46c527b39360e0544c4aa1ad7b01255daf5bb67'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0xAA5c4244F05c92781C4F259913319d8ba1aCF05E',
#  'mixHash': HexBytes('0x1982277d44effa81846b3418ee014553a38b674f603e07ce9f9be7bbaedabb92'),
#  'nonce': HexBytes('0x21b8de40000f0e52'),
#  'number': 8927400,
#  'parentHash': HexBytes('0x4b101e50adad2291e6f44e5399486512a6682a092bc983f821a3face8d8abcdc'),
#  'receiptsRoot': HexBytes('0x81c8427defbe3ba157b9a3ba58706d7dff4cdf6c6084f59b83836e049fad800b'),
#  'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#  'size': 11866,
#  'stateRoot': HexBytes('0xed77c2fcd0ca7d798c9c5e6bd1ea822d746e264acad6f1c98973ec7505362e62'),
#  'timestamp': 1573662095,
#  'totalDifficulty': 12834843182239540601036,
#  'transactions': [HexBytes('0x6b053b1615e047cfeff3ae36cce1ed655b7df004252d45190cb5eeb589cc35a0'),
#   HexBytes('0xe8bef2ddf7801aec592b5a3eb763280b8d7a56a6d0440dc2b13b0864dd834e6b'),
#   HexBytes('0x1beeaa72141230f6f7938b5fff953ccae364a3b94b7568cb1c81a97edeb9195c'),
#   HexBytes('0xea0f1d971a237a4b8c82418f79dc6dc05baf77ec71cc1b81462a7f044026749d'),
#   HexBytes('0x2a27dc26e3ecd55c8426e9dcdca5196262e0ed3de0a980172a35c95e0ad8478f'),
#   HexBytes('0x1f08210e2753321dab542b094fac795fc11f14899ed418a6487b100f589d14d6'),
#   HexBytes('0x39d86f6326a2950b92ddbf4de3263b78df1d8bee5adfe89422e1a9b2890ca142'),
#   HexBytes('0x7ffbb157dc46852246a3843f335ec8e5c3d119c47109d3940d414251c6763b28'),
#   HexBytes('0xa628034cb8a9b0b37eebec25f553b37a71910f82d4dbf071771437683fe4934c'),
#   HexBytes('0x9a3abfaaeffe346e8bfdec8e47c464a3917ef1044337a7dcc92e3d3b48f65b7f'),
#   HexBytes('0x82217b549bc9ef1b6162f87827d67fa83b5d44f36bd39e5490e3dc1bb145bfed'),
#   HexBytes('0x68b866ec48f0eed241f6c9ba0af83a559c53e59dc0a9bc98329ff8e08d4b89c7'),
#   HexBytes('0x7fa56a1607b286ee4acfa753d8070e359657f49ef6fb71b209b9a80af25ea0dd'),
#   HexBytes('0x9f8cb58414de9d49aede0c8b0e7f8c958cc115eba93b33035a9565ee8e5b888d'),
#   HexBytes('0x902da60ae00435b0f62e8a33b18982ae839efb611297e37c44c60b9819aacbf9'),
#   HexBytes('0x2021d72fe11b10317c6f7bcf9c1fd6cb57599910fbc18c5df3d2aca6e49b0471'),
#   HexBytes('0x1ee90ad7f1994c33fbee45cbbd80bc03bacd9355ac89274f1ecf82030a6c4d69'),
#   HexBytes('0xc40010120e88cfbc183219c1d745749936f669af89ad6d179efb3b1554277b82'),
#   HexBytes('0xbf948df32b17d85acaf438d6a1dbb6c77a38b9afc121459cc3585dd518ea6209'),
#   HexBytes('0x28bcf20d1a3609daa578daf04d230843d5a0cce38ae940c5382e7b099aff70c6'),
#   HexBytes('0xef9ec1ec3b4193eb11068d8975791d79183eab9eda7044218c399a3c3fc5c5eb'),
#   HexBytes('0xa97241f5008ed7a8eeead740bc2b0a1766688cbf6f5a76e285920f86f7770ef5'),
#   HexBytes('0x94b33d7422ff1a13382160f68b218cab0deccd40ee1f55a5224f0043193e31aa'),
#   HexBytes('0x95015c6f479b51d497b61be85a030106665d04712eeedb1a64feccd8fc89e9c4'),
#   HexBytes('0x6e0fa0e29de4a069cd99078c6774270877ea505e7e2b084eb06f642c08662370'),
#   HexBytes('0x0e077eab801afd00678cb5ed08852d44a8266fb10548f8e0ddedef697ff1eb7c'),
#   HexBytes('0x0d2bed92369c6c95b588e6351ef6a9720422b2303f66296694c5c5ea0fedb4b1'),
#   HexBytes('0xaf237e7aa3f0d895a511407f0e38c5a8a826b1f1885d9a5a6103235b413560e3'),
#   HexBytes('0x18d97964306e153a03bd4872938659f99ce3b7a61d758c2c3e95b46635213ef6'),
#   HexBytes('0x6a0f47f1ce759a509f2292bb8f229eb4d6c5e644adf75c3bc097cc23921e3c7c'),
#   HexBytes('0x5894cee5a11b6e04fc3d851a80b95f2500bd726e03a6979b1af6b3f4eaec3c2f')],
#  'transactionsRoot': HexBytes('0x8e14977f600653acd6844ec288f35332b2efb6e9981df70230eccfb9a4205753'),
#  'uncles': []})

# %%
web3.eth.getTransaction('0x5894cee5a11b6e04fc3d851a80b95f2500bd726e03a6979b1af6b3f4eaec3c2f')
# Out:
# AttributeDict({'blockHash': HexBytes('0xb8766ec72e3c3779bbe2fccad46c527b39360e0544c4aa1ad7b01255daf5bb67'),
#  'blockNumber': 8927400,
#  'from': '0x780dc27a176445Aa93bBF3c80753196e41f916eC',
#  'gas': 66000,
#  'gasPrice': 3000000000,
#  'hash': HexBytes('0x5894cee5a11b6e04fc3d851a80b95f2500bd726e03a6979b1af6b3f4eaec3c2f'),
#  'input': '0xa9059cbb0000000000000000000000005e22774f6103a940c552017ff62ad6a59849da1f00000000000000000000000000000000000000000000009d6bb5407a78d60000',
#  'nonce': 3304,
#  'r': HexBytes('0x4d4697f6a3c67e684668c995c141bed13c60bc6c068c6073ec7d1168ab228251'),
#  's': HexBytes('0x17e02d0868e0cb97f4631be793952efa094ce5fbb43fcb453b386437333c14fc'),
#  'to': '0x5d285F735998F36631F678FF41fb56A10A4d0429',
#  'transactionIndex': 30,
#  'v': 37,
#  'value': 0})

# %%
sum = 0
for place in bla.transactions:
    check = web3.eth.getTransactionReceipt(place)
    sum += check.gasUsed
sum
# Out:
# 3133147
