# %%
import os
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = "http://www.moscow_city.vybory.izbirkom.ru/region/region/moscow_city?action=show&root=1&tvd=27720002197406&vrn=27720002197402&region=77&global=&sub_region=77&prver=0&pronetvd=null&vibid=27720002197406&type=222"

# %%
response = requests.get(url)
response.encoding = 'cp1251'
htmlString = response.text
page = BeautifulSoup(htmlString, "html.parser")

# %%
dump_folder = 'tmp'

# %%
table_inner_titles = page.find('table', align="left", cellpadding="2", cellspacing="1", vspace="0")
rows = table_inner_titles.find_all('tr')
#print (len(rows))
#print (table_inner_titles.prettify())
for rows in table_inner_titles.find_all('tr'):
    cols = table_inner_titles.find_all('td')

titles = []
for place in cols[3:35:3]:
    titles.append(place.text)
titles

total_number = []
for place in cols[4:36:3]:
    total_number.append(place.text[:len(place.text)-2])
total_number

candidates = []
for place in cols[38::3]:
    candidates.append(place.text)
candidates

cand_votes = []
cand_votes_percent = []
for place in cols[39::3]:
    stop = place.text.index('\n')
    cand_votes.append(place.text[:stop])

# %%
table_all_nums = page.find('table', align="left", bgcolor="#ffffff", border="0", cellpadding="2", cellspacing="1", style="width:100%;overflow:scroll", vspace="0")
#print (table_all_nums.prettify())
rows = table_all_nums.find_all('tr')
for row in table_all_nums.find_all('tr'):
    cols = row.find_all('a')
links = rows[0].find_all('a')
districts = []
for link in links:
    districts.append(link.text)

# %%
numbers_dict = dict.fromkeys(titles)
for num, title in enumerate(numbers_dict):
    all_votes = rows[num + 1].find_all('b')
    numbers_dict[title] = [total_number[num]] + [all_vote.text for all_vote in all_votes]
numbers_dict

# %%
cands_dict = dict.fromkeys(candidates)
for num, place in enumerate(cands_dict):
    all_votes = rows[num + 13].find_all('b')
    cands_dict[place] = [cand_votes[num]] + [all_vote.text for all_vote in all_votes]

# %%
#cands_dict
#disctricts
#numbers_dict
df_cands = pd.DataFrame(cands_dict)
df_cands
df_votes = pd.DataFrame(numbers_dict)
df_votes
# Out:
#     Число избирателей, внесенных в список Число бюллетеней, полученных УИК  \
# 0                                 7301064                          5718568
# 1                                   62663                            48000
# 2                                   76911                            61150
# 3                                   40553                            30500
# 4                                  100703                            75200
# ..                                    ...                              ...
# 124                                 64687                            51429
# 125                                 92388                            69885
# 126                                 93986                            69070
# 127                                100254                            87545
# 128                                 96150                            74315
#
#     Число бюллетеней, выданных в помещении для голосования  \
# 0                                              2109453
# 1                                                18092
# 2                                                23264
# 3                                                12055
# 4                                                25844
# ..                                                 ...
# 124                                              19045
# 125                                              25933
# 126                                              35016
# 127                                              39476
# 128                                              35091
#
#     Число бюллетеней, выданных вне помещения для голосования  \
# 0                                               149627
# 1                                                 1034
# 2                                                 2239
# 3                                                 1616
# 4                                                 2136
# ..                                                 ...
# 124                                               1361
# 125                                               1747
# 126                                                828
# 127                                               2660
# 128                                                716
#
#     Число погашенных бюллетеней  \
# 0                       3459473
# 1                         28873
# 2                         35647
# 3                         16829
# 4                         47220
# ..                          ...
# 124                       31023
# 125                       42205
# 126                       33220
# 127                       45409
# 128                       38515
#
#     Число бюллетеней, содержащихся в переносных ящиках  \
# 0                                               149535
# 1                                                 1034
# 2                                                 2239
# 3                                                 1616
# 4                                                 2136
# ..                                                 ...
# 124                                               1361
# 125                                               1747
# 126                                                828
# 127                                               2660
# 128                                                716
#
#     Число бюллетеней, содержащихся в стационарных ящиках  \
# 0                                              2106162
# 1                                                18059
# 2                                                23183
# 3                                                12031
# 4                                                25823
# ..                                                 ...
# 124                                              19033
# 125                                              25892
# 126                                              34943
# 127                                              39472
# 128                                              34876
#
#     Число недействительных бюллетеней Число действительных бюллетеней  \
# 0                               64278                         2191419
# 1                                 607                           18486
# 2                                 771                           24651
# 3                                 472                           13175
# 4                                 850                           27109
# ..                                ...                             ...
# 124                               526                           19868
# 125                               644                           26995
# 126                               915                           34856
# 127                               992                           41140
# 128                               976                           34616
#
#     Число утраченных бюллетеней Число бюллетеней, не учтенных при получении
# 0                            31                                          16
# 1                             1                                           0
# 2                             0                                           0
# 3                             0                                           0
# 4                             0                                           0
# ..                          ...                                         ...
# 124                           0                                           0
# 125                           0                                           0
# 126                           6                                           0
# 127                           0                                           0
# 128                           5                                          12
#
# [129 rows x 11 columns]

# %%
district = ['Total'] + districts
df_votes['District'] = district
df_votes
# Out:
#     Число избирателей, внесенных в список Число бюллетеней, полученных УИК  \
# 0                                 7301064                          5718568
# 1                                   62663                            48000
# 2                                   76911                            61150
# 3                                   40553                            30500
# 4                                  100703                            75200
# ..                                    ...                              ...
# 124                                 64687                            51429
# 125                                 92388                            69885
# 126                                 93986                            69070
# 127                                100254                            87545
# 128                                 96150                            74315
#
#     Число бюллетеней, выданных в помещении для голосования  \
# 0                                              2109453
# 1                                                18092
# 2                                                23264
# 3                                                12055
# 4                                                25844
# ..                                                 ...
# 124                                              19045
# 125                                              25933
# 126                                              35016
# 127                                              39476
# 128                                              35091
#
#     Число бюллетеней, выданных вне помещения для голосования  \
# 0                                               149627
# 1                                                 1034
# 2                                                 2239
# 3                                                 1616
# 4                                                 2136
# ..                                                 ...
# 124                                               1361
# 125                                               1747
# 126                                                828
# 127                                               2660
# 128                                                716
#
#     Число погашенных бюллетеней  \
# 0                       3459473
# 1                         28873
# 2                         35647
# 3                         16829
# 4                         47220
# ..                          ...
# 124                       31023
# 125                       42205
# 126                       33220
# 127                       45409
# 128                       38515
#
#     Число бюллетеней, содержащихся в переносных ящиках  \
# 0                                               149535
# 1                                                 1034
# 2                                                 2239
# 3                                                 1616
# 4                                                 2136
# ..                                                 ...
# 124                                               1361
# 125                                               1747
# 126                                                828
# 127                                               2660
# 128                                                716
#
#     Число бюллетеней, содержащихся в стационарных ящиках  \
# 0                                              2106162
# 1                                                18059
# 2                                                23183
# 3                                                12031
# 4                                                25823
# ..                                                 ...
# 124                                              19033
# 125                                              25892
# 126                                              34943
# 127                                              39472
# 128                                              34876
#
#     Число недействительных бюллетеней Число действительных бюллетеней  \
# 0                               64278                         2191419
# 1                                 607                           18486
# 2                                 771                           24651
# 3                                 472                           13175
# 4                                 850                           27109
# ..                                ...                             ...
# 124                               526                           19868
# 125                               644                           26995
# 126                               915                           34856
# 127                               992                           41140
# 128                               976                           34616
#
#     Число утраченных бюллетеней Число бюллетеней, не учтенных при получении  \
# 0                            31                                          16
# 1                             1                                           0
# 2                             0                                           0
# 3                             0                                           0
# 4                             0                                           0
# ..                          ...                                         ...
# 124                           0                                           0
# 125                           0                                           0
# 126                           6                                           0
# 127                           0                                           0
# 128                           5                                          12
#
#                             District
# 0                              Total
# 1                  район Богородское
# 2                     район Вешняки
# 3         район Восточное Измайлово
# 4                   район Гольяново
# ..                               ...
# 124      район Чертаново Центральное
# 125            район Чертаново Южное
# 126                   Новомосковская
# 127  Троицкий административный округ
# 128                        Сосенская
#
# [129 rows x 12 columns]

# %%
df_cands.to_csv(os.path.join(dump_folder, ('candidates.csv')), sep=';')
df_votes.to_csv(os.path.join(dump_folder, ('votes.csv')), sep=';')
